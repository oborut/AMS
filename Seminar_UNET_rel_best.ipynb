# %%
# SEMINAR IZ BIOMEDICINSKE TEHNIKE 2019-2020
# MODEL UNET 1

# %%
# 1. INICIALIZACIJA

# %%
# Nalaganje knjižnic

import os
import sys
import random
import warnings

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from scipy.stats import ttest_rel, ttest_ind, wilcoxon, mannwhitneyu

import keras
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose, Conv3D, Conv3DTranspose
from keras.layers.pooling import MaxPooling2D, MaxPooling3D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

import amslib_seminar
import importlib
importlib.reload(amslib_seminar)
from amslib_seminar import load_mri_brain_data, load_mri_brain_data_classifications
# Out:
# Using TensorFlow backend.

# %%
# Določitev parametrov.

# Nastavitev željene velikosti slik za učenje 1. modela (unet2d).
IMG_WIDTH=192
IMG_HEIGHT=192
IMG_DEPTH=1
NO_SLICES=1

# Določitev možnih modalitet.
# OPOMBA: v kolikor podamo le eno modaliteto, moramo dati na koncu vejico, sicer prevajalnik prepozna spremenljivko kot skalar in ne kot seznam.
MODALITIES1=('flair_02') # Modalitete za detekcijo sprememb.
MODALITIES2=('flair_01','flair_02')
MODALITIES=MODALITIES2

# Določitev tipa podatkov.
DTYPE='float16'

# Določitev mape z modeli.
MODELS_PATH='models'

# Določitev imena datoteke s shranjenim modelom.
# OPOMBA: pomen posameznih vrednosti:
# - sbmt/ams: model ustvarjen za Seminar iz Biomedicinske tehnike ali za seminar Analiza medicinskih slik.
# - unet/cnn/dense: arhitektura modela.
# - 1/3/16/32/64/128/192: število aksialnih rezin.
# - 192-192/128-128/64-64/32-32/16-16: dimenzije aksialnih rezin.
# - 1/2/3/4/5: število modalitet.
# - f16/f32/f64: označuje podatkovni tip s plavajočo vejico.
# - j/c: označuje, ali je bil model ustvarjen na PC-ju v okolju Jupyterlab ali na spletu v okolju Google Colab.
MODEL_NAME1='ams-unet1-1-192-192-1-f16-j.h5'
MODEL_NAME2='ams-unet1-1-192-192-2-f16-j.h5'
MODEL_NAME=MODEL_NAME2

# Določitev mejne spremembe skupnega volumna lezij za aktivno MS.
DV_THRESHOLD=0
# OPOMBA: prag arbitrarno določen glede na razporeditev sprememb volumnov v beležki Seminar_referenca.

# Določitev mejnih sprememb skupnega volumna lezij za aktivno MS za posamezne izbire rezin.
DV_THRESHOLD_2D=0 # v cm**2

# Določitev semena za generacijo vedno istega zaporedja psevdonaključnih števil.
SEED = 42

# Določitev deleža testnih podatkov.
TEST_DATA_FRACTION = 0.3

# Določitev števila razredov pri razvrščanju.
NUM_CLASSES = 2 # binarno razvrščanje (lahko tudi več kategorij oz. oznak)

# Določitev hiperparametrov pri učenju.
BATCH_SIZE = 32
NUM_EPOCHS = 100
LEARNING_RATE = 1e-3

# Nastavitev praga razvrščanja.
THRESHOLD = 0.5

# %%
# 2. PRIPRAVA PODATKOV

# %%
# Definicija funkcije za izris vzorca učnih podatkov.

def viewImagesInput2d(X_train,Y0_train,Y1_train,Y01_train,MODALITIES):

    # Check if training data looks all right
    ix = random.randint(0, X_train.shape[0]-1)
    # OPOMBA: v funkcijo dodana vrednost -1, sicer lahko pri izbiranju slik z indeksom za 1 prekoračimo nabor možnih slik.
    _, _, num_modalities = X_train[ix].shape

    titles = [m.upper() + ' slika' for m in MODALITIES] + ['Maska 1','Maska 2','Referenčna razgradnja']
    f, ax = plt.subplots(1, num_modalities+3, sharex=True, sharey=True, figsize=(20, 5))
    for i in range(num_modalities):
        ax[i].imshow(X_train[ix][:,:,i].astype('float32'), cmap='gray')
        ax[i].set_title(titles[i])
        ax[i].axis('off')
    ax[-3].imshow(np.squeeze(Y0_train[ix][:,:].astype('float32')))
    ax[-3].set_title(titles[-3])
    ax[-2].imshow(np.squeeze(Y1_train[ix][:,:].astype('float32')))
    ax[-2].set_title(titles[-2])
    ax[-1].imshow(np.squeeze(Y01_train[ix][:,:].astype('float32')))
    ax[-1].set_title(titles[-1])
    # OPOMBA: pretvorbo v format float32 pri prikazovanju opravimo, ker imshow ne podpira formata float16.

# %%
# Nalaganje referenčnih podatkov o klasifikacijah.
Y=load_mri_brain_data_classifications(dV_threshold=DV_THRESHOLD,dtype=DTYPE)

# Izpis lastnosti podatkov.
print('Velikost izhodnih podatkov:',Y.shape)
print('Možne vrednosti izhodnih podatkov',np.unique(Y))
print('Tip izhodnih podatkov:',Y.dtype)
MSn=np.count_nonzero(Y[:,0])
MSa=np.count_nonzero(Y[:,1])
print('Število pacientov z neaktivno MS: {:d}'.format(MSn))
print('Število pacientov z aktivno MS: {:d}'.format(MSa))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 162/162 [00:13<00:00, 11.99it/s]
# Velikost izhodnih podatkov: (162, 2)
# Možne vrednosti izhodnih podatkov [0. 1.]
# Tip izhodnih podatkov: float16
# Število pacientov z neaktivno MS: 73
# Število pacientov z aktivno MS: 89

# %%
# Nalaganje vhodnih podatkov pri učenju (slike in maske).
X,Y0,Y1=load_mri_brain_data(output_size=(IMG_WIDTH,IMG_HEIGHT,IMG_DEPTH),no_slices=NO_SLICES,modalities=MODALITIES,dtype=DTYPE)
# Izločitev aksialne (Z) dimenzije.
X,Y0,Y1=np.squeeze(X),np.squeeze(Y0),np.squeeze(Y1)
if X.ndim!=4:
    X=X[:,:,:,np.newaxis]
if Y1.ndim!=4:
    Y0=Y0[:,:,:,np.newaxis]    
if Y1.ndim!=4:
    Y1=Y1[:,:,:,np.newaxis]
# OPOMBA: v primeru ene modalitete numpy funkcija squeeze izloči tudi zadnjo dimenzijo. V primeru, da število dimenzij ni zmanjšano iz 5 na 4, ustvarimo na koncu ponovno dodatno dimenzijo.

# Izračun razlike mask.
Y01=(Y0!=Y1).astype('float16')

# Izračun spremembe volumna iz sredinskih rezin referenčnih mask.

# Referenčna maska M1.
Vs1=np.sum(np.sum((np.squeeze(Y0==1)),axis=-1),axis=-1)/100 # Pretvorba iz mm**2 v cm**2.
# Referenčna maska M2.
Vs2=np.sum(np.sum((np.squeeze(Y1)==1),axis=-1),axis=-1)/100 # Pretvorba iz mm**2 v cm**2.
# Razlika M2-M1.
Y2D=Vs2-Vs1 # Podano v cm**2.

# Klasifikacija na podlagi spremembe volumna sredinskih lezij referenčnih mask.

# OPOMBA: prag arbitrarno določen glede na razporeditev sprememb volumnov v beležki Seminar_referenca.
Y2D_t=np.zeros_like(Y2D)
Y2D_t[Y2D>DV_THRESHOLD_2D]=1
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 162/162 [02:41<00:00,  1.01it/s]

# %%
# Razdelitev podatkov na učne in testne.
X_train,X_test,Y_train,Y_test,Y0_train,Y0_test,Y1_train,Y1_test,Y01_train,Y01_test,Vs1_train,Vs1_test,Vs2_train,Vs2_test,Y2D_train,Y2D_test,Y2D_train_t,Y2D_test_t=train_test_split(X,Y,Y0,Y1,Y01,Vs1,Vs2,Y2D,Y2D_t,test_size=TEST_DATA_FRACTION,random_state=SEED)
# OPOMBA: v funkciji moramo eksplicitno določitev fiksno razdelitev na učne in testne podatke, saj funkcija ne prepozna zunanje nastavitve np.random.seed in vzorče še vedno deli ob vsakem
# klicu drugače.

print('Velikost podatkovnih polj za učenje: X_train={}, Y_train={}'.format(X_train.shape,Y01_train.shape))
print('Velikost podatkovnih polj za testiranje: X_test={}, Y_test={}'.format(X_test.shape,Y01_test.shape))
print('')
print('Velikost podatkovnih polj za učenje v MB: X_train={} MB, Y_train={} MB'.format(X_train.size*X_train.itemsize/2**20,Y01_train.size*Y01_train.itemsize/2**20))
print('Velikost podatkovnih polj za testiranje v MB: X_test={} MB, Y_test={} MB'.format(X_test.size*X_test.itemsize/2**20,Y01_test.size*Y01_test.itemsize/2**20))
print('')
print('Tip podatkovnih polj za učenje: X_train={}, Y_train={}'.format(X_train.dtype,Y01_train.dtype))
print('Tip podatkovnih polj za testiranje: X_test={}, Y_test={}'.format(X_test.dtype,Y01_test.dtype))
# Out:
# Velikost podatkovnih polj za učenje: X_train=(113, 192, 192, 2), Y_train=(113, 192, 192, 1)
# Velikost podatkovnih polj za testiranje: X_test=(49, 192, 192, 2), Y_test=(49, 192, 192, 1)
#
# Velikost podatkovnih polj za učenje v MB: X_train=15.890625 MB, Y_train=7.9453125 MB
# Velikost podatkovnih polj za testiranje v MB: X_test=6.890625 MB, Y_test=3.4453125 MB
#
# Tip podatkovnih polj za učenje: X_train=float16, Y_train=float16
# Tip podatkovnih polj za testiranje: X_test=float16, Y_test=float16

# %%
# Izris vzorca učnih podatkov.
viewImagesInput2d(X_train,Y0_train,Y1_train,Y01_train,MODALITIES)

# %%
# NAČRTOVANJE IN UČENJE MODELA

# %%
# Definicija funkcije za izgradnjo U-net mreže.

# 2D U-net mreža, ki opravlja konvolucijo čez sredinsko rezino slike dimenzije NxN.
def unet2d_v1(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):
    
    # vhodna plast
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    
    S=Lambda(lambda x: x)(inputs)
    
    C1=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(S)
    C1=Dropout(0.1)(C1)
    C1=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C1)
    
    P1=MaxPooling2D((2,2))(C1)
    C2=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P1)
    C2=Dropout(0.1)(C2)
    C2=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C2)
    
    P2=MaxPooling2D((2,2))(C2)
    C3=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P2)
    C3=Dropout(0.2)(C3)
    C3=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C3)
    
    P3=MaxPooling2D((2,2))(C3)
    C4=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P3)
    C4=Dropout(0.2)(C4)
    C4=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C4)
    
    P4=MaxPooling2D((2,2))(C4)
    C5=Conv2D(256,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P4)
    C5=Dropout(0.3)(C5)
    C5=Conv2D(256,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C5)
    
    U6=Conv2DTranspose(128,(2,2),strides=(2,2),padding='same')(C5) # Izvedba nadvzorčenja.
    U6=concatenate([U6,C4]) # Združitev dveh plasti.
    C6=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U6)
    C6=Dropout(0.2)(C6)
    C6=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C6)
    
    U7=Conv2DTranspose(64,(2,2),strides=(2,2),padding='same')(C6)
    U7=concatenate([U7,C3])
    C7=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U7)
    C7=Dropout(0.2)(C7)
    C7=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C7)
    
    U8=Conv2DTranspose(32,(2,2),strides=(2,2),padding='same')(C7)
    U8=concatenate([U8,C2])
    C8=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U8)
    C8=Dropout(0.1)(C8)
    C8=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C8)
    
    U9=Conv2DTranspose(16,(2,2),strides=(2,2),padding='same')(C8)
    U9=concatenate([U9,C1])
    C9=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U9)
    C9=Dropout(0.1)(C9)
    C9=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C9)
    
    outputs=Conv2D(1,(1,1),activation='sigmoid')(C9)
    model=Model(inputs=[inputs],outputs=[outputs])
    
    # povzetek modela
    model.summary()
    
    return model

# 2D U-net mreža, ki opravlja konvolucijo čez sredinsko rezino slike dimenzije NxN.
def unet2d_v2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):
    
    # vhodna plast
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    
    S=Lambda(lambda x: x)(inputs)
    
    C1=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(S)
    C1=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C1)
    C1=BatchNormalization()(C1)
    C1=Dropout(0.1)(C1)
    C1=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C1)
    C1=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C1)
    
    P1=MaxPooling2D((2,2))(C1)
    P1=BatchNormalization()(P1)
    P1=Dropout(0.1)(P1)
    C2=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P1)
    C2=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C2)
    
    P2=MaxPooling2D((2,2))(C2)
    P2=BatchNormalization()(P2)
    P2=Dropout(0.1)(P2)
    C3=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P2)
    C3=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C3)
    
    P3=MaxPooling2D((2,2))(C3)
    P3=BatchNormalization()(P3)
    P3=Dropout(0.2)(P3)
    C4=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P3)
    C4=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C4)
    
    P4=MaxPooling2D((2,2))(C4)
    P4=BatchNormalization()(P4)
    P4=Dropout(0.2)(P4)
    C5=Conv2D(256,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(P4)
    C5=Conv2D(256,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C5)
    
    U6=Conv2DTranspose(128,(2,2),strides=(2,2),padding='same')(C5) # Izvedba nadvzorčenja.
    U6=concatenate([U6,C4]) # Združitev dveh plasti.
    U6=BatchNormalization()(U6)
    U6=Dropout(0.2)(U6)
    C6=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U6)
    C6=Conv2D(128,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C6)
    
    U7=Conv2DTranspose(64,(2,2),strides=(2,2),padding='same')(C6)
    U7=concatenate([U7,C3])
    U7=BatchNormalization()(U7)
    U7=Dropout(0.1)(U7)
    C7=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U7)
    C7=Conv2D(64,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C7)
    
    U8=Conv2DTranspose(32,(2,2),strides=(2,2),padding='same')(C7)
    U8=concatenate([U8,C2])
    U8=BatchNormalization()(U8)
    U8=Dropout(0.1)(U8)
    C8=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U8)
    C8=Conv2D(32,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C8)
    
    U9=Conv2DTranspose(16,(2,2),strides=(2,2),padding='same')(C8)
    U9=concatenate([U9,C1])
    U9=BatchNormalization()(U9)
    U9=Dropout(0.1)(U9)
    C9=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(U9)
    C9=Conv2D(16,(3,3),activation='elu',kernel_initializer='he_normal',padding='same')(C9)
    
    outputs=Conv2D(1,(1,1),activation='sigmoid')(C9)
    model=Model(inputs=[inputs],outputs=[outputs])
    
    # povzetek modela
    model.summary()
    
    return model

# %%
# Definicija kriterijskih funkcij

def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def iou_coef(y_true, y_pred, smooth=1):
    """
    IoU = (|X &amp; Y|)/ (|X or Y|)
    """
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    return (intersection + smooth) / ( union + smooth)

def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

def dice_coef(y_true, y_pred):
    """
    DSC = (2*|X &amp; Y|)/ (|X| + |Y|)
    """    
    smooth = 1
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def weighted_cross_entropy(y_true, y_pred):
    # OPOMBA: prirejeno po https://lars76.github.io/neural-networks/object-detection/losses-for-segmentation/.
    
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    # beta=K.sum(y_true==0)/K.sum(y_true==1) # izračun iz deleža enic in ničel v podatkih.
    BETA=5 # ročno določeno
    # OPOMBA: s povečanjem beta zmanjšamo delež FN, z zmanjšanjem beta pa zmanjšamo delež FP.
    
    y_pred_f=K.clip(y_pred_f, K.epsilon(), 1 - K.epsilon())
    y_pred_f=K.log(y_pred_f / (1 - y_pred_f))
    
    WCE = tf.nn.weighted_cross_entropy_with_logits(logits=y_pred_f, targets=y_true_f, pos_weight=BETA)
        
    # or reduce_sum and/or axis=-1
    return K.mean(WCE)

# OPOMBA: kriterijske funkcije se med učenjem izračunavajo le z namenom prikaza in niso uporabljene za samo učenje.

# %%
# Izgradnja modela.
model=unet2d_v1(IMG_HEIGHT, IMG_WIDTH, len(MODALITIES))
# Out:
# WARNING:tensorflow:From E:\Borut\PROGRAMI\WPy64-3741\python-3.7.4.amd64\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From E:\Borut\PROGRAMI\WPy64-3741\python-3.7.4.amd64\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 192, 192, 2)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 192, 192, 2)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 16) 304         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 192, 192, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 192, 192, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 96, 96, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 96, 96, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 96, 96, 32)   9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 48, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 48, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 24, 128)  73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 24, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 12, 256)  295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 24, 24, 128)  131200      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 24, 24, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 24, 24, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 24, 24, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 48, 48, 64)   32832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 48, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 48, 48, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 48, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 96, 96, 32)   8224        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 96, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 96, 96, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 96, 64)   18496       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 192, 192, 16) 4112        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 192, 192, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 192, 192, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 192, 192, 16) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 192, 192, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 192, 192, 1)  17          conv2d_18[0][0]
# ==================================================================================================
# Total params: 1,952,257
# Trainable params: 1,952,257
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Prevajanje modela v strojno kodo.
model.compile(optimizer=keras.optimizers.Adam(lr=LEARNING_RATE), loss=keras.losses.binary_crossentropy, metrics=[dice_coef])
# OPOMBA: druge optimizacijske metode: Adadelta, RMSprop, SGD,...
# OPOMBA: ker je število vokslov, ki pripadajo kategoriji lezij, majhno, bi bilo dobro razreda uravnotežiti z nastavitvijo parametra class_weights. Vendar parameter ni uporaben v primeru
# večdimenzionalnih vhodov, pri nastavitvi alternativnega parametra samples_weights pa je izhod potrebno pretvoriti v 1D časovno zaporedje, kar je nepraktično.

# Uporaba lastne funkcije za izračunavanje utežene binarne križne entropije.
# model.compile(optimizer=keras.optimizers.Adam(lr=LEARNING_RATE), loss=weighted_cross_entropy, metrics=[dice_coef])

# %%
# Zagon učenja modela.
earlystopper = EarlyStopping(monitor='loss',patience=5, verbose=1)
checkpointer = ModelCheckpoint(os.path.join(MODELS_PATH, MODEL_NAME), monitor='loss', verbose=1, save_best_only=True)
model.fit(X_train, Y01_train, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS, verbose=1, validation_data=(X_test, Y01_test), callbacks=[earlystopper, checkpointer])
# OPOMBA: model manj parametrov kot sekvenčni model za razvrščanje, vendar vzame več časa za izračun posameznih epoh.
# OPOMBA: pri večkratnem zaporednem učenju se zgleda uteži ne generirajo vsakič znova, ampak se učenje začne z njihovimi trenutno naučenimi vrednostmi.
# OPOMBA: pri večkratnem zaporednem učenju se rezultati izboljšujejo predvsem na učnim zbirki, na katero se uteži vedno bolje prilegajo, ne pa na testni zbirki.
# OPOMBA: Pri večkratnem ponavljanju učenja dobimo podoben rezultat neglede na nastavitev uteži v kriterijski funkciji BCE.
# OPOMBA: model unet_v1 daje na začetku veliko FN rezultatov, model unet_v2 pa veliko FP.
# Out:
# Train on 113 samples, validate on 49 samples
# Epoch 1/100
# 113/113 [==============================] - ETA: 14s - loss: 0.0122 - dice_coef: 0.36 - ETA: 7s - loss: 0.0292 - dice_coef: 0.1841 - ETA: 2s - loss: 0.0274 - dice_coef: 0.143 - 20s 175ms/step - loss: 0.0257 - dice_coef: 0.1231 - val_loss: 0.0218 - val_dice_coef: 0.0446
#
# Epoch 00001: loss improved from inf to 0.02573, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 2/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0213 - dice_coef: 0.05 - ETA: 7s - loss: 0.0192 - dice_coef: 0.0564 - ETA: 2s - loss: 0.0185 - dice_coef: 0.063 - 18s 162ms/step - loss: 0.0176 - dice_coef: 0.0634 - val_loss: 0.0156 - val_dice_coef: 0.0705
#
# Epoch 00002: loss improved from 0.02573 to 0.01763, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 3/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0167 - dice_coef: 0.06 - ETA: 7s - loss: 0.0149 - dice_coef: 0.0678 - ETA: 2s - loss: 0.0157 - dice_coef: 0.074 - 18s 163ms/step - loss: 0.0153 - dice_coef: 0.0805 - val_loss: 0.0142 - val_dice_coef: 0.1232
#
# Epoch 00003: loss improved from 0.01763 to 0.01528, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 4/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0142 - dice_coef: 0.09 - ETA: 7s - loss: 0.0154 - dice_coef: 0.1163 - ETA: 2s - loss: 0.0143 - dice_coef: 0.118 - 19s 165ms/step - loss: 0.0142 - dice_coef: 0.1204 - val_loss: 0.0134 - val_dice_coef: 0.1284
#
# Epoch 00004: loss improved from 0.01528 to 0.01415, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 5/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0119 - dice_coef: 0.12 - ETA: 7s - loss: 0.0139 - dice_coef: 0.1258 - ETA: 2s - loss: 0.0125 - dice_coef: 0.125 - 18s 158ms/step - loss: 0.0133 - dice_coef: 0.1303 - val_loss: 0.0131 - val_dice_coef: 0.1587
#
# Epoch 00005: loss improved from 0.01415 to 0.01329, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 6/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0129 - dice_coef: 0.15 - ETA: 7s - loss: 0.0123 - dice_coef: 0.1526 - ETA: 2s - loss: 0.0133 - dice_coef: 0.159 - 18s 161ms/step - loss: 0.0127 - dice_coef: 0.1597 - val_loss: 0.0124 - val_dice_coef: 0.1700
#
# Epoch 00006: loss improved from 0.01329 to 0.01270, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 7/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0106 - dice_coef: 0.15 - ETA: 7s - loss: 0.0111 - dice_coef: 0.1573 - ETA: 2s - loss: 0.0128 - dice_coef: 0.161 - 18s 162ms/step - loss: 0.0122 - dice_coef: 0.1614 - val_loss: 0.0123 - val_dice_coef: 0.1692
#
# Epoch 00007: loss improved from 0.01270 to 0.01224, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 8/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0117 - dice_coef: 0.17 - ETA: 7s - loss: 0.0121 - dice_coef: 0.1822 - ETA: 2s - loss: 0.0116 - dice_coef: 0.179 - 18s 163ms/step - loss: 0.0116 - dice_coef: 0.1756 - val_loss: 0.0121 - val_dice_coef: 0.1727
#
# Epoch 00008: loss improved from 0.01224 to 0.01161, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 9/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0104 - dice_coef: 0.16 - ETA: 7s - loss: 0.0111 - dice_coef: 0.1713 - ETA: 2s - loss: 0.0116 - dice_coef: 0.178 - 18s 159ms/step - loss: 0.0113 - dice_coef: 0.1814 - val_loss: 0.0122 - val_dice_coef: 0.1705
#
# Epoch 00009: loss improved from 0.01161 to 0.01130, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 10/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0124 - dice_coef: 0.17 - ETA: 7s - loss: 0.0118 - dice_coef: 0.1907 - ETA: 2s - loss: 0.0113 - dice_coef: 0.193 - 18s 164ms/step - loss: 0.0110 - dice_coef: 0.1929 - val_loss: 0.0122 - val_dice_coef: 0.1893
#
# Epoch 00010: loss improved from 0.01130 to 0.01096, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 11/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0110 - dice_coef: 0.19 - ETA: 7s - loss: 0.0102 - dice_coef: 0.1940 - ETA: 2s - loss: 0.0106 - dice_coef: 0.201 - 18s 163ms/step - loss: 0.0107 - dice_coef: 0.2150 - val_loss: 0.0122 - val_dice_coef: 0.1942
#
# Epoch 00011: loss improved from 0.01096 to 0.01073, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 12/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0108 - dice_coef: 0.24 - ETA: 7s - loss: 0.0113 - dice_coef: 0.2293 - ETA: 2s - loss: 0.0104 - dice_coef: 0.226 - 18s 164ms/step - loss: 0.0105 - dice_coef: 0.2216 - val_loss: 0.0123 - val_dice_coef: 0.1943
#
# Epoch 00012: loss improved from 0.01073 to 0.01051, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 13/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0092 - dice_coef: 0.20 - ETA: 7s - loss: 0.0105 - dice_coef: 0.2270 - ETA: 2s - loss: 0.0106 - dice_coef: 0.228 - 18s 160ms/step - loss: 0.0102 - dice_coef: 0.2239 - val_loss: 0.0123 - val_dice_coef: 0.1937
#
# Epoch 00013: loss improved from 0.01051 to 0.01018, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 14/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0114 - dice_coef: 0.23 - ETA: 7s - loss: 0.0114 - dice_coef: 0.2443 - ETA: 2s - loss: 0.0103 - dice_coef: 0.233 - 19s 166ms/step - loss: 0.0100 - dice_coef: 0.2257 - val_loss: 0.0123 - val_dice_coef: 0.1946
#
# Epoch 00014: loss improved from 0.01018 to 0.01002, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 15/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0106 - dice_coef: 0.22 - ETA: 7s - loss: 0.0096 - dice_coef: 0.2285 - ETA: 2s - loss: 0.0100 - dice_coef: 0.240 - 18s 159ms/step - loss: 0.0098 - dice_coef: 0.2419 - val_loss: 0.0125 - val_dice_coef: 0.2004
#
# Epoch 00015: loss improved from 0.01002 to 0.00982, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 16/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0100 - dice_coef: 0.27 - ETA: 7s - loss: 0.0104 - dice_coef: 0.2646 - ETA: 2s - loss: 0.0095 - dice_coef: 0.254 - 18s 158ms/step - loss: 0.0097 - dice_coef: 0.2527 - val_loss: 0.0127 - val_dice_coef: 0.2076
#
# Epoch 00016: loss improved from 0.00982 to 0.00967, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 17/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0096 - dice_coef: 0.29 - ETA: 7s - loss: 0.0098 - dice_coef: 0.2660 - ETA: 2s - loss: 0.0097 - dice_coef: 0.264 - 18s 159ms/step - loss: 0.0095 - dice_coef: 0.2657 - val_loss: 0.0125 - val_dice_coef: 0.2063
#
# Epoch 00017: loss improved from 0.00967 to 0.00953, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 18/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0089 - dice_coef: 0.25 - ETA: 7s - loss: 0.0098 - dice_coef: 0.2562 - ETA: 2s - loss: 0.0095 - dice_coef: 0.262 - 18s 160ms/step - loss: 0.0093 - dice_coef: 0.2662 - val_loss: 0.0127 - val_dice_coef: 0.2050
#
# Epoch 00018: loss improved from 0.00953 to 0.00934, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 19/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0094 - dice_coef: 0.26 - ETA: 7s - loss: 0.0095 - dice_coef: 0.2807 - ETA: 2s - loss: 0.0092 - dice_coef: 0.273 - 18s 163ms/step - loss: 0.0092 - dice_coef: 0.2731 - val_loss: 0.0128 - val_dice_coef: 0.2129
#
# Epoch 00019: loss improved from 0.00934 to 0.00924, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 20/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0094 - dice_coef: 0.28 - ETA: 7s - loss: 0.0096 - dice_coef: 0.2960 - ETA: 2s - loss: 0.0094 - dice_coef: 0.282 - 19s 166ms/step - loss: 0.0091 - dice_coef: 0.2814 - val_loss: 0.0128 - val_dice_coef: 0.2142
#
# Epoch 00020: loss improved from 0.00924 to 0.00913, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 21/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0072 - dice_coef: 0.27 - ETA: 7s - loss: 0.0095 - dice_coef: 0.2913 - ETA: 2s - loss: 0.0093 - dice_coef: 0.289 - 19s 164ms/step - loss: 0.0090 - dice_coef: 0.2864 - val_loss: 0.0129 - val_dice_coef: 0.2164
#
# Epoch 00021: loss improved from 0.00913 to 0.00902, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 22/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0101 - dice_coef: 0.32 - ETA: 7s - loss: 0.0097 - dice_coef: 0.3117 - ETA: 2s - loss: 0.0092 - dice_coef: 0.295 - 19s 164ms/step - loss: 0.0089 - dice_coef: 0.2902 - val_loss: 0.0131 - val_dice_coef: 0.2105
#
# Epoch 00022: loss improved from 0.00902 to 0.00893, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 23/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0092 - dice_coef: 0.27 - ETA: 7s - loss: 0.0091 - dice_coef: 0.2856 - ETA: 2s - loss: 0.0091 - dice_coef: 0.298 - 18s 158ms/step - loss: 0.0089 - dice_coef: 0.2874 - val_loss: 0.0133 - val_dice_coef: 0.2154
#
# Epoch 00023: loss improved from 0.00893 to 0.00889, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 24/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0078 - dice_coef: 0.30 - ETA: 7s - loss: 0.0085 - dice_coef: 0.3165 - ETA: 2s - loss: 0.0085 - dice_coef: 0.309 - 18s 158ms/step - loss: 0.0088 - dice_coef: 0.3060 - val_loss: 0.0132 - val_dice_coef: 0.2163
#
# Epoch 00024: loss improved from 0.00889 to 0.00879, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 25/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0092 - dice_coef: 0.33 - ETA: 7s - loss: 0.0091 - dice_coef: 0.3306 - ETA: 2s - loss: 0.0088 - dice_coef: 0.312 - 18s 160ms/step - loss: 0.0086 - dice_coef: 0.3036 - val_loss: 0.0131 - val_dice_coef: 0.2144
#
# Epoch 00025: loss improved from 0.00879 to 0.00864, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 26/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0079 - dice_coef: 0.30 - ETA: 7s - loss: 0.0084 - dice_coef: 0.3155 - ETA: 2s - loss: 0.0086 - dice_coef: 0.315 - 19s 165ms/step - loss: 0.0086 - dice_coef: 0.3126 - val_loss: 0.0133 - val_dice_coef: 0.2192
#
# Epoch 00026: loss improved from 0.00864 to 0.00862, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 27/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0090 - dice_coef: 0.33 - ETA: 7s - loss: 0.0092 - dice_coef: 0.3124 - ETA: 2s - loss: 0.0087 - dice_coef: 0.313 - 19s 167ms/step - loss: 0.0085 - dice_coef: 0.3242 - val_loss: 0.0134 - val_dice_coef: 0.2162
#
# Epoch 00027: loss improved from 0.00862 to 0.00855, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 28/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0091 - dice_coef: 0.30 - ETA: 7s - loss: 0.0086 - dice_coef: 0.3056 - ETA: 2s - loss: 0.0084 - dice_coef: 0.320 - 18s 159ms/step - loss: 0.0085 - dice_coef: 0.3192 - val_loss: 0.0133 - val_dice_coef: 0.2215
#
# Epoch 00028: loss improved from 0.00855 to 0.00855, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 29/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0088 - dice_coef: 0.33 - ETA: 7s - loss: 0.0085 - dice_coef: 0.3393 - ETA: 2s - loss: 0.0085 - dice_coef: 0.330 - 18s 158ms/step - loss: 0.0084 - dice_coef: 0.3307 - val_loss: 0.0134 - val_dice_coef: 0.2195
#
# Epoch 00029: loss improved from 0.00855 to 0.00840, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 30/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0083 - dice_coef: 0.37 - ETA: 7s - loss: 0.0086 - dice_coef: 0.3406 - ETA: 2s - loss: 0.0085 - dice_coef: 0.328 - 18s 160ms/step - loss: 0.0084 - dice_coef: 0.3252 - val_loss: 0.0137 - val_dice_coef: 0.2211
#
# Epoch 00030: loss improved from 0.00840 to 0.00839, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 31/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0089 - dice_coef: 0.34 - ETA: 7s - loss: 0.0082 - dice_coef: 0.3362 - ETA: 2s - loss: 0.0084 - dice_coef: 0.324 - 18s 159ms/step - loss: 0.0084 - dice_coef: 0.3354 - val_loss: 0.0139 - val_dice_coef: 0.2181
#
# Epoch 00031: loss improved from 0.00839 to 0.00835, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 32/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0082 - dice_coef: 0.34 - ETA: 7s - loss: 0.0085 - dice_coef: 0.3573 - ETA: 2s - loss: 0.0084 - dice_coef: 0.345 - 18s 160ms/step - loss: 0.0083 - dice_coef: 0.3361 - val_loss: 0.0135 - val_dice_coef: 0.2174
#
# Epoch 00032: loss improved from 0.00835 to 0.00828, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 33/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0080 - dice_coef: 0.33 - ETA: 7s - loss: 0.0085 - dice_coef: 0.3405 - ETA: 2s - loss: 0.0083 - dice_coef: 0.347 - 18s 157ms/step - loss: 0.0082 - dice_coef: 0.3301 - val_loss: 0.0135 - val_dice_coef: 0.2199
#
# Epoch 00033: loss improved from 0.00828 to 0.00824, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 34/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0078 - dice_coef: 0.35 - ETA: 7s - loss: 0.0077 - dice_coef: 0.3481 - ETA: 2s - loss: 0.0078 - dice_coef: 0.337 - 18s 158ms/step - loss: 0.0082 - dice_coef: 0.3449 - val_loss: 0.0136 - val_dice_coef: 0.2274
#
# Epoch 00034: loss improved from 0.00824 to 0.00820, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 35/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0083 - dice_coef: 0.33 - ETA: 7s - loss: 0.0079 - dice_coef: 0.3335 - ETA: 2s - loss: 0.0084 - dice_coef: 0.349 - 18s 158ms/step - loss: 0.0081 - dice_coef: 0.3394 - val_loss: 0.0141 - val_dice_coef: 0.2175
#
# Epoch 00035: loss improved from 0.00820 to 0.00814, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 36/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0075 - dice_coef: 0.33 - ETA: 7s - loss: 0.0080 - dice_coef: 0.3394 - ETA: 2s - loss: 0.0080 - dice_coef: 0.341 - 18s 161ms/step - loss: 0.0081 - dice_coef: 0.3558 - val_loss: 0.0137 - val_dice_coef: 0.2181
#
# Epoch 00036: loss improved from 0.00814 to 0.00812, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 37/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0071 - dice_coef: 0.33 - ETA: 7s - loss: 0.0075 - dice_coef: 0.3362 - ETA: 2s - loss: 0.0081 - dice_coef: 0.349 - 18s 162ms/step - loss: 0.0081 - dice_coef: 0.3431 - val_loss: 0.0137 - val_dice_coef: 0.2217
#
# Epoch 00037: loss improved from 0.00812 to 0.00807, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 38/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0083 - dice_coef: 0.33 - ETA: 7s - loss: 0.0083 - dice_coef: 0.3394 - ETA: 2s - loss: 0.0078 - dice_coef: 0.350 - 18s 159ms/step - loss: 0.0080 - dice_coef: 0.3667 - val_loss: 0.0138 - val_dice_coef: 0.2137
#
# Epoch 00038: loss improved from 0.00807 to 0.00802, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 39/100
# 113/113 [==============================] - ETA: 12s - loss: 0.0066 - dice_coef: 0.33 - ETA: 7s - loss: 0.0077 - dice_coef: 0.3473 - ETA: 2s - loss: 0.0078 - dice_coef: 0.352 - 18s 160ms/step - loss: 0.0079 - dice_coef: 0.3540 - val_loss: 0.0141 - val_dice_coef: 0.2274
#
# Epoch 00039: loss improved from 0.00802 to 0.00793, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 40/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0080 - dice_coef: 0.39 - ETA: 7s - loss: 0.0076 - dice_coef: 0.3876 - ETA: 2s - loss: 0.0079 - dice_coef: 0.379 - 18s 159ms/step - loss: 0.0079 - dice_coef: 0.3639 - val_loss: 0.0140 - val_dice_coef: 0.2107
#
# Epoch 00040: loss improved from 0.00793 to 0.00788, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 41/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0089 - dice_coef: 0.40 - ETA: 7s - loss: 0.0079 - dice_coef: 0.3784 - ETA: 2s - loss: 0.0078 - dice_coef: 0.361 - 18s 161ms/step - loss: 0.0079 - dice_coef: 0.3583 - val_loss: 0.0139 - val_dice_coef: 0.2226
#
# Epoch 00041: loss improved from 0.00788 to 0.00787, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 42/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0075 - dice_coef: 0.40 - ETA: 7s - loss: 0.0069 - dice_coef: 0.3681 - ETA: 2s - loss: 0.0075 - dice_coef: 0.368 - 18s 157ms/step - loss: 0.0078 - dice_coef: 0.3653 - val_loss: 0.0141 - val_dice_coef: 0.2241
#
# Epoch 00042: loss improved from 0.00787 to 0.00780, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 43/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0071 - dice_coef: 0.35 - ETA: 7s - loss: 0.0070 - dice_coef: 0.3509 - ETA: 2s - loss: 0.0077 - dice_coef: 0.370 - 18s 157ms/step - loss: 0.0078 - dice_coef: 0.3697 - val_loss: 0.0142 - val_dice_coef: 0.2129
#
# Epoch 00043: loss did not improve from 0.00780
# Epoch 44/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0068 - dice_coef: 0.33 - ETA: 7s - loss: 0.0073 - dice_coef: 0.3607 - ETA: 2s - loss: 0.0076 - dice_coef: 0.373 - 18s 158ms/step - loss: 0.0077 - dice_coef: 0.3643 - val_loss: 0.0141 - val_dice_coef: 0.2222
#
# Epoch 00044: loss improved from 0.00780 to 0.00772, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 45/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0078 - dice_coef: 0.35 - ETA: 7s - loss: 0.0079 - dice_coef: 0.3744 - ETA: 2s - loss: 0.0078 - dice_coef: 0.383 - 18s 159ms/step - loss: 0.0077 - dice_coef: 0.3750 - val_loss: 0.0141 - val_dice_coef: 0.2161
#
# Epoch 00045: loss did not improve from 0.00772
# Epoch 46/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0070 - dice_coef: 0.35 - ETA: 7s - loss: 0.0078 - dice_coef: 0.3668 - ETA: 2s - loss: 0.0080 - dice_coef: 0.371 - 18s 157ms/step - loss: 0.0077 - dice_coef: 0.3661 - val_loss: 0.0145 - val_dice_coef: 0.2339
#
# Epoch 00046: loss improved from 0.00772 to 0.00772, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 47/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0072 - dice_coef: 0.37 - ETA: 7s - loss: 0.0074 - dice_coef: 0.4067 - ETA: 2s - loss: 0.0074 - dice_coef: 0.385 - 18s 159ms/step - loss: 0.0077 - dice_coef: 0.3831 - val_loss: 0.0140 - val_dice_coef: 0.2077
#
# Epoch 00047: loss improved from 0.00772 to 0.00769, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 48/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0073 - dice_coef: 0.34 - ETA: 7s - loss: 0.0073 - dice_coef: 0.3738 - ETA: 2s - loss: 0.0072 - dice_coef: 0.377 - 18s 157ms/step - loss: 0.0076 - dice_coef: 0.3836 - val_loss: 0.0141 - val_dice_coef: 0.2238
#
# Epoch 00048: loss improved from 0.00769 to 0.00762, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 49/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0081 - dice_coef: 0.42 - ETA: 7s - loss: 0.0078 - dice_coef: 0.3943 - ETA: 2s - loss: 0.0075 - dice_coef: 0.381 - 18s 158ms/step - loss: 0.0076 - dice_coef: 0.3766 - val_loss: 0.0144 - val_dice_coef: 0.2190
#
# Epoch 00049: loss improved from 0.00762 to 0.00757, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 50/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0070 - dice_coef: 0.40 - ETA: 7s - loss: 0.0066 - dice_coef: 0.3941 - ETA: 2s - loss: 0.0074 - dice_coef: 0.398 - 18s 157ms/step - loss: 0.0076 - dice_coef: 0.3908 - val_loss: 0.0144 - val_dice_coef: 0.2147
#
# Epoch 00050: loss did not improve from 0.00757
# Epoch 51/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0069 - dice_coef: 0.34 - ETA: 7s - loss: 0.0074 - dice_coef: 0.3554 - ETA: 2s - loss: 0.0078 - dice_coef: 0.376 - 18s 158ms/step - loss: 0.0076 - dice_coef: 0.3749 - val_loss: 0.0144 - val_dice_coef: 0.2279
#
# Epoch 00051: loss improved from 0.00757 to 0.00755, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 52/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0067 - dice_coef: 0.43 - ETA: 7s - loss: 0.0069 - dice_coef: 0.4110 - ETA: 2s - loss: 0.0074 - dice_coef: 0.403 - 18s 158ms/step - loss: 0.0074 - dice_coef: 0.4047 - val_loss: 0.0144 - val_dice_coef: 0.2173
#
# Epoch 00052: loss improved from 0.00755 to 0.00742, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 53/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0083 - dice_coef: 0.39 - ETA: 7s - loss: 0.0076 - dice_coef: 0.4016 - ETA: 2s - loss: 0.0073 - dice_coef: 0.399 - 18s 158ms/step - loss: 0.0074 - dice_coef: 0.3900 - val_loss: 0.0149 - val_dice_coef: 0.2238
#
# Epoch 00053: loss improved from 0.00742 to 0.00740, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 54/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0066 - dice_coef: 0.39 - ETA: 7s - loss: 0.0071 - dice_coef: 0.4092 - ETA: 2s - loss: 0.0074 - dice_coef: 0.411 - 18s 160ms/step - loss: 0.0073 - dice_coef: 0.4075 - val_loss: 0.0147 - val_dice_coef: 0.2054
#
# Epoch 00054: loss improved from 0.00740 to 0.00734, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 55/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0074 - dice_coef: 0.38 - ETA: 7s - loss: 0.0076 - dice_coef: 0.3971 - ETA: 2s - loss: 0.0076 - dice_coef: 0.402 - 18s 158ms/step - loss: 0.0074 - dice_coef: 0.3897 - val_loss: 0.0143 - val_dice_coef: 0.2238
#
# Epoch 00055: loss did not improve from 0.00734
# Epoch 56/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0073 - dice_coef: 0.39 - ETA: 7s - loss: 0.0072 - dice_coef: 0.3981 - ETA: 2s - loss: 0.0074 - dice_coef: 0.401 - 18s 158ms/step - loss: 0.0073 - dice_coef: 0.4169 - val_loss: 0.0145 - val_dice_coef: 0.2226
#
# Epoch 00056: loss improved from 0.00734 to 0.00729, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 57/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0072 - dice_coef: 0.42 - ETA: 7s - loss: 0.0073 - dice_coef: 0.4134 - ETA: 2s - loss: 0.0073 - dice_coef: 0.415 - 18s 158ms/step - loss: 0.0072 - dice_coef: 0.4035 - val_loss: 0.0146 - val_dice_coef: 0.2217
#
# Epoch 00057: loss improved from 0.00729 to 0.00725, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 58/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0068 - dice_coef: 0.36 - ETA: 7s - loss: 0.0074 - dice_coef: 0.4192 - ETA: 2s - loss: 0.0074 - dice_coef: 0.411 - 18s 159ms/step - loss: 0.0072 - dice_coef: 0.3982 - val_loss: 0.0144 - val_dice_coef: 0.2228
#
# Epoch 00058: loss improved from 0.00725 to 0.00722, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 59/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0068 - dice_coef: 0.39 - ETA: 7s - loss: 0.0073 - dice_coef: 0.4079 - ETA: 2s - loss: 0.0073 - dice_coef: 0.419 - 18s 158ms/step - loss: 0.0071 - dice_coef: 0.4090 - val_loss: 0.0146 - val_dice_coef: 0.2290
#
# Epoch 00059: loss improved from 0.00722 to 0.00714, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 60/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0069 - dice_coef: 0.46 - ETA: 7s - loss: 0.0069 - dice_coef: 0.4400 - ETA: 2s - loss: 0.0071 - dice_coef: 0.421 - 18s 158ms/step - loss: 0.0071 - dice_coef: 0.4237 - val_loss: 0.0151 - val_dice_coef: 0.2174
#
# Epoch 00060: loss improved from 0.00714 to 0.00713, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 61/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0076 - dice_coef: 0.41 - ETA: 7s - loss: 0.0072 - dice_coef: 0.4084 - ETA: 2s - loss: 0.0068 - dice_coef: 0.410 - 18s 158ms/step - loss: 0.0071 - dice_coef: 0.4244 - val_loss: 0.0147 - val_dice_coef: 0.2282
#
# Epoch 00061: loss improved from 0.00713 to 0.00710, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 62/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0079 - dice_coef: 0.42 - ETA: 7s - loss: 0.0073 - dice_coef: 0.4156 - ETA: 2s - loss: 0.0070 - dice_coef: 0.429 - 18s 158ms/step - loss: 0.0071 - dice_coef: 0.4215 - val_loss: 0.0153 - val_dice_coef: 0.2182
#
# Epoch 00062: loss improved from 0.00710 to 0.00709, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 63/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0079 - dice_coef: 0.42 - ETA: 7s - loss: 0.0073 - dice_coef: 0.4115 - ETA: 2s - loss: 0.0073 - dice_coef: 0.424 - 18s 158ms/step - loss: 0.0072 - dice_coef: 0.4201 - val_loss: 0.0150 - val_dice_coef: 0.2214
#
# Epoch 00063: loss did not improve from 0.00709
# Epoch 64/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0065 - dice_coef: 0.46 - ETA: 7s - loss: 0.0072 - dice_coef: 0.4412 - ETA: 2s - loss: 0.0069 - dice_coef: 0.428 - 18s 160ms/step - loss: 0.0070 - dice_coef: 0.4192 - val_loss: 0.0153 - val_dice_coef: 0.2220
#
# Epoch 00064: loss improved from 0.00709 to 0.00704, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 65/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0076 - dice_coef: 0.48 - ETA: 7s - loss: 0.0073 - dice_coef: 0.4391 - ETA: 2s - loss: 0.0070 - dice_coef: 0.429 - 18s 158ms/step - loss: 0.0070 - dice_coef: 0.4275 - val_loss: 0.0153 - val_dice_coef: 0.2123
#
# Epoch 00065: loss improved from 0.00704 to 0.00698, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 66/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0069 - dice_coef: 0.38 - ETA: 7s - loss: 0.0065 - dice_coef: 0.3982 - ETA: 2s - loss: 0.0070 - dice_coef: 0.422 - 18s 158ms/step - loss: 0.0070 - dice_coef: 0.4280 - val_loss: 0.0155 - val_dice_coef: 0.2248
#
# Epoch 00066: loss did not improve from 0.00698
# Epoch 67/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0075 - dice_coef: 0.45 - ETA: 7s - loss: 0.0070 - dice_coef: 0.4382 - ETA: 2s - loss: 0.0069 - dice_coef: 0.429 - 18s 158ms/step - loss: 0.0069 - dice_coef: 0.4335 - val_loss: 0.0153 - val_dice_coef: 0.2254
#
# Epoch 00067: loss improved from 0.00698 to 0.00693, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 68/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0072 - dice_coef: 0.47 - ETA: 7s - loss: 0.0073 - dice_coef: 0.4548 - ETA: 2s - loss: 0.0072 - dice_coef: 0.443 - 18s 158ms/step - loss: 0.0069 - dice_coef: 0.4299 - val_loss: 0.0153 - val_dice_coef: 0.2136
#
# Epoch 00068: loss improved from 0.00693 to 0.00688, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 69/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0069 - dice_coef: 0.41 - ETA: 7s - loss: 0.0071 - dice_coef: 0.4345 - ETA: 2s - loss: 0.0070 - dice_coef: 0.443 - 18s 159ms/step - loss: 0.0069 - dice_coef: 0.4369 - val_loss: 0.0152 - val_dice_coef: 0.2214
#
# Epoch 00069: loss improved from 0.00688 to 0.00688, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 70/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0073 - dice_coef: 0.43 - ETA: 7s - loss: 0.0070 - dice_coef: 0.4296 - ETA: 2s - loss: 0.0072 - dice_coef: 0.438 - 18s 158ms/step - loss: 0.0068 - dice_coef: 0.4372 - val_loss: 0.0152 - val_dice_coef: 0.2277
#
# Epoch 00070: loss improved from 0.00688 to 0.00683, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 71/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0070 - dice_coef: 0.44 - ETA: 7s - loss: 0.0068 - dice_coef: 0.4601 - ETA: 2s - loss: 0.0068 - dice_coef: 0.458 - 18s 158ms/step - loss: 0.0068 - dice_coef: 0.4410 - val_loss: 0.0158 - val_dice_coef: 0.2125
#
# Epoch 00071: loss improved from 0.00683 to 0.00683, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 72/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0079 - dice_coef: 0.45 - ETA: 7s - loss: 0.0070 - dice_coef: 0.4497 - ETA: 2s - loss: 0.0070 - dice_coef: 0.451 - 18s 158ms/step - loss: 0.0068 - dice_coef: 0.4400 - val_loss: 0.0151 - val_dice_coef: 0.2352
#
# Epoch 00072: loss improved from 0.00683 to 0.00677, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 73/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0073 - dice_coef: 0.44 - ETA: 7s - loss: 0.0070 - dice_coef: 0.4679 - ETA: 2s - loss: 0.0067 - dice_coef: 0.449 - 18s 158ms/step - loss: 0.0067 - dice_coef: 0.4404 - val_loss: 0.0153 - val_dice_coef: 0.2194
#
# Epoch 00073: loss improved from 0.00677 to 0.00673, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 74/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0062 - dice_coef: 0.44 - ETA: 7s - loss: 0.0068 - dice_coef: 0.4651 - ETA: 2s - loss: 0.0067 - dice_coef: 0.460 - 18s 158ms/step - loss: 0.0067 - dice_coef: 0.4548 - val_loss: 0.0158 - val_dice_coef: 0.2268
#
# Epoch 00074: loss improved from 0.00673 to 0.00670, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 75/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0074 - dice_coef: 0.46 - ETA: 7s - loss: 0.0065 - dice_coef: 0.4466 - ETA: 2s - loss: 0.0067 - dice_coef: 0.453 - 18s 158ms/step - loss: 0.0067 - dice_coef: 0.4489 - val_loss: 0.0152 - val_dice_coef: 0.2218
#
# Epoch 00075: loss improved from 0.00670 to 0.00668, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 76/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0070 - dice_coef: 0.49 - ETA: 7s - loss: 0.0066 - dice_coef: 0.4631 - ETA: 2s - loss: 0.0066 - dice_coef: 0.453 - 18s 158ms/step - loss: 0.0066 - dice_coef: 0.4592 - val_loss: 0.0157 - val_dice_coef: 0.2216
#
# Epoch 00076: loss improved from 0.00668 to 0.00661, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 77/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0059 - dice_coef: 0.47 - ETA: 7s - loss: 0.0063 - dice_coef: 0.4624 - ETA: 2s - loss: 0.0064 - dice_coef: 0.462 - 18s 159ms/step - loss: 0.0066 - dice_coef: 0.4523 - val_loss: 0.0161 - val_dice_coef: 0.2282
#
# Epoch 00077: loss did not improve from 0.00661
# Epoch 78/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0056 - dice_coef: 0.46 - ETA: 7s - loss: 0.0063 - dice_coef: 0.4728 - ETA: 2s - loss: 0.0061 - dice_coef: 0.463 - 18s 157ms/step - loss: 0.0066 - dice_coef: 0.4668 - val_loss: 0.0160 - val_dice_coef: 0.2116
#
# Epoch 00078: loss improved from 0.00661 to 0.00658, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 79/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0063 - dice_coef: 0.44 - ETA: 7s - loss: 0.0062 - dice_coef: 0.4385 - ETA: 2s - loss: 0.0064 - dice_coef: 0.440 - 18s 158ms/step - loss: 0.0065 - dice_coef: 0.4620 - val_loss: 0.0159 - val_dice_coef: 0.2414
#
# Epoch 00079: loss improved from 0.00658 to 0.00652, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 80/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0076 - dice_coef: 0.46 - ETA: 7s - loss: 0.0071 - dice_coef: 0.4677 - ETA: 2s - loss: 0.0066 - dice_coef: 0.478 - 18s 158ms/step - loss: 0.0066 - dice_coef: 0.4652 - val_loss: 0.0159 - val_dice_coef: 0.2045
#
# Epoch 00080: loss did not improve from 0.00652
# Epoch 81/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0064 - dice_coef: 0.45 - ETA: 7s - loss: 0.0068 - dice_coef: 0.4730 - ETA: 2s - loss: 0.0066 - dice_coef: 0.467 - 18s 158ms/step - loss: 0.0065 - dice_coef: 0.4678 - val_loss: 0.0166 - val_dice_coef: 0.2296
#
# Epoch 00081: loss improved from 0.00652 to 0.00649, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 82/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0069 - dice_coef: 0.47 - ETA: 7s - loss: 0.0069 - dice_coef: 0.4891 - ETA: 2s - loss: 0.0064 - dice_coef: 0.477 - 18s 158ms/step - loss: 0.0065 - dice_coef: 0.4620 - val_loss: 0.0161 - val_dice_coef: 0.2205
#
# Epoch 00082: loss improved from 0.00649 to 0.00645, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 83/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0060 - dice_coef: 0.43 - ETA: 7s - loss: 0.0058 - dice_coef: 0.4452 - ETA: 2s - loss: 0.0064 - dice_coef: 0.471 - 18s 158ms/step - loss: 0.0064 - dice_coef: 0.4710 - val_loss: 0.0164 - val_dice_coef: 0.2313
#
# Epoch 00083: loss improved from 0.00645 to 0.00639, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 84/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0054 - dice_coef: 0.48 - ETA: 7s - loss: 0.0059 - dice_coef: 0.4794 - ETA: 2s - loss: 0.0061 - dice_coef: 0.472 - 18s 158ms/step - loss: 0.0063 - dice_coef: 0.4849 - val_loss: 0.0159 - val_dice_coef: 0.2182
#
# Epoch 00084: loss improved from 0.00639 to 0.00635, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 85/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0065 - dice_coef: 0.50 - ETA: 7s - loss: 0.0062 - dice_coef: 0.4832 - ETA: 2s - loss: 0.0064 - dice_coef: 0.484 - 18s 157ms/step - loss: 0.0063 - dice_coef: 0.4783 - val_loss: 0.0162 - val_dice_coef: 0.2271
#
# Epoch 00085: loss improved from 0.00635 to 0.00633, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 86/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0056 - dice_coef: 0.46 - ETA: 7s - loss: 0.0061 - dice_coef: 0.4855 - ETA: 2s - loss: 0.0061 - dice_coef: 0.484 - 18s 158ms/step - loss: 0.0064 - dice_coef: 0.4773 - val_loss: 0.0163 - val_dice_coef: 0.2251
#
# Epoch 00086: loss did not improve from 0.00633
# Epoch 87/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0066 - dice_coef: 0.48 - ETA: 7s - loss: 0.0060 - dice_coef: 0.4715 - ETA: 2s - loss: 0.0063 - dice_coef: 0.488 - 18s 158ms/step - loss: 0.0062 - dice_coef: 0.4909 - val_loss: 0.0163 - val_dice_coef: 0.2167
#
# Epoch 00087: loss improved from 0.00633 to 0.00624, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 88/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0064 - dice_coef: 0.46 - ETA: 7s - loss: 0.0061 - dice_coef: 0.4665 - ETA: 2s - loss: 0.0061 - dice_coef: 0.483 - 18s 158ms/step - loss: 0.0063 - dice_coef: 0.4766 - val_loss: 0.0161 - val_dice_coef: 0.2315
#
# Epoch 00088: loss did not improve from 0.00624
# Epoch 89/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0058 - dice_coef: 0.46 - ETA: 7s - loss: 0.0058 - dice_coef: 0.4727 - ETA: 2s - loss: 0.0064 - dice_coef: 0.492 - 18s 158ms/step - loss: 0.0062 - dice_coef: 0.4858 - val_loss: 0.0165 - val_dice_coef: 0.2160
#
# Epoch 00089: loss improved from 0.00624 to 0.00623, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 90/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0066 - dice_coef: 0.49 - ETA: 7s - loss: 0.0066 - dice_coef: 0.5068 - ETA: 2s - loss: 0.0064 - dice_coef: 0.487 - 18s 157ms/step - loss: 0.0062 - dice_coef: 0.4907 - val_loss: 0.0167 - val_dice_coef: 0.2281
#
# Epoch 00090: loss improved from 0.00623 to 0.00615, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 91/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0067 - dice_coef: 0.51 - ETA: 7s - loss: 0.0067 - dice_coef: 0.5013 - ETA: 2s - loss: 0.0064 - dice_coef: 0.506 - 18s 158ms/step - loss: 0.0062 - dice_coef: 0.4866 - val_loss: 0.0170 - val_dice_coef: 0.2103
#
# Epoch 00091: loss did not improve from 0.00615
# Epoch 92/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0080 - dice_coef: 0.46 - ETA: 7s - loss: 0.0069 - dice_coef: 0.4821 - ETA: 2s - loss: 0.0064 - dice_coef: 0.494 - 18s 157ms/step - loss: 0.0062 - dice_coef: 0.4901 - val_loss: 0.0170 - val_dice_coef: 0.2297
#
# Epoch 00092: loss did not improve from 0.00615
# Epoch 93/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0055 - dice_coef: 0.47 - ETA: 7s - loss: 0.0058 - dice_coef: 0.4888 - ETA: 2s - loss: 0.0061 - dice_coef: 0.501 - 18s 158ms/step - loss: 0.0061 - dice_coef: 0.4936 - val_loss: 0.0165 - val_dice_coef: 0.2115
#
# Epoch 00093: loss improved from 0.00615 to 0.00614, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 94/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0062 - dice_coef: 0.47 - ETA: 7s - loss: 0.0061 - dice_coef: 0.4850 - ETA: 2s - loss: 0.0059 - dice_coef: 0.487 - 18s 158ms/step - loss: 0.0060 - dice_coef: 0.5071 - val_loss: 0.0166 - val_dice_coef: 0.2316
#
# Epoch 00094: loss improved from 0.00614 to 0.00601, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 95/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0065 - dice_coef: 0.52 - ETA: 7s - loss: 0.0061 - dice_coef: 0.4939 - ETA: 2s - loss: 0.0062 - dice_coef: 0.500 - 18s 157ms/step - loss: 0.0061 - dice_coef: 0.4994 - val_loss: 0.0164 - val_dice_coef: 0.2207
#
# Epoch 00095: loss did not improve from 0.00601
# Epoch 96/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0076 - dice_coef: 0.52 - ETA: 7s - loss: 0.0063 - dice_coef: 0.5128 - ETA: 2s - loss: 0.0060 - dice_coef: 0.513 - 18s 158ms/step - loss: 0.0060 - dice_coef: 0.5124 - val_loss: 0.0168 - val_dice_coef: 0.2296
#
# Epoch 00096: loss improved from 0.00601 to 0.00596, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 97/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0063 - dice_coef: 0.53 - ETA: 7s - loss: 0.0063 - dice_coef: 0.5301 - ETA: 2s - loss: 0.0063 - dice_coef: 0.513 - 18s 157ms/step - loss: 0.0060 - dice_coef: 0.5015 - val_loss: 0.0170 - val_dice_coef: 0.2206
#
# Epoch 00097: loss did not improve from 0.00596
# Epoch 98/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0062 - dice_coef: 0.51 - ETA: 7s - loss: 0.0060 - dice_coef: 0.5003 - ETA: 2s - loss: 0.0058 - dice_coef: 0.507 - 18s 159ms/step - loss: 0.0059 - dice_coef: 0.5178 - val_loss: 0.0170 - val_dice_coef: 0.2279
#
# Epoch 00098: loss improved from 0.00596 to 0.00592, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 99/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0056 - dice_coef: 0.55 - ETA: 7s - loss: 0.0061 - dice_coef: 0.5454 - ETA: 2s - loss: 0.0060 - dice_coef: 0.521 - 18s 158ms/step - loss: 0.0058 - dice_coef: 0.5088 - val_loss: 0.0172 - val_dice_coef: 0.2280
#
# Epoch 00099: loss improved from 0.00592 to 0.00581, saving model to models\ams-unet1-1-192-192-2-f16-j.h5
# Epoch 100/100
# 113/113 [==============================] - ETA: 11s - loss: 0.0057 - dice_coef: 0.55 - ETA: 7s - loss: 0.0051 - dice_coef: 0.5320 - ETA: 2s - loss: 0.0058 - dice_coef: 0.522 - 18s 157ms/step - loss: 0.0058 - dice_coef: 0.5237 - val_loss: 0.0173 - val_dice_coef: 0.2248
#
# Epoch 00100: loss did not improve from 0.00581

# %%
# 4. VREDNOTENJE RAZGRADNJE

# %%
# Definicija funkcij za kvalitativno vrednotenje rezultatov.

def viewImagesOutput2d(X, Y01, preds_t, Y0, Y1, preds_m, MODALITIES):
    ix = random.randint(0, len(preds_t)-1)
    # OPOMBA: v funkcijo dodana vrednost -1, sicer lahko pri izbiranju slik z indeksom za 1 prekoračimo nabor možnih slik.
    _, _, num_modalities = X[ix].shape

    titles = [m.upper() + ' slika' for m in MODALITIES] + ['M2-M1 (ref)', 'M2-M1 (U-net)', 'M1 (ref)','M2 (ref)', 'M2 (U-Net)']
    f, ax = plt.subplots(1, num_modalities+5, sharex=True, sharey=True, figsize=(20, 5))
    for i in range(num_modalities):
        ax[i].imshow(X[ix][:,:,i].astype('float32'), cmap='gray')
        ax[i].set_title(titles[i])
        ax[i].axis('off')
    # prikaži izhodiščni maski
    ax[-5].imshow(np.squeeze(Y01[ix].astype('float32')))
    ax[-5].set_title(titles[-5])
    ax[-5].axis('off')
    ax[-4].imshow(np.squeeze(preds_t[ix].astype('float32')))
    ax[-4].set_title(titles[-4])
    ax[-4].axis('off')  
    # prikaži referenčno razgradnjo
    ax[-3].imshow(np.squeeze(Y0[ix].astype('float32')))
    ax[-3].set_title(titles[-3])
    ax[-3].axis('off')
    ax[-2].imshow(np.squeeze(Y1[ix].astype('float32')))
    ax[-2].set_title(titles[-2])
    ax[-2].axis('off')
    # prikaži razgradnjo z U-net
    ax[-1].imshow(np.squeeze(preds_m[ix]))
    ax[-1].set_title(titles[-1])
    ax[-1].axis('off')
    # OPOMBA: pretvorbo v format float32 pri prikazovanju opravimo, ker imshow ne podpira formata float16.
    
def viewImagesOutputMS2d(X, Y, preds_t, MODALITIES):
    Y=Y.astype('int')
    preds_t=preds_t.astype('int')
    ix = random.randint(0, len(preds_t)-1)
    # OPOMBA: v funkcijo dodana vrednost -1, sicer lahko pri izbiranju slik z indeksom za 1 prekoračimo nabor možnih slik.
    _, _, num_modalities = X[ix].shape

    titles = [m.upper() + ' slika' for m in MODALITIES] + ['Referenčna klasifikacija', 'Klasifikacija z U-net']
    f, ax = plt.subplots(1, num_modalities+2, sharex=True, sharey=True, figsize=(20, 5))
    for i in range(num_modalities):
        ax[i].imshow(X[ix][:,:,i].astype('float32'), cmap='gray')
        ax[i].set_title(titles[i])
        ax[i].axis('off')
    Yplot=np.ones((X.shape[1],X.shape[2]))
    Yplot[:,0]=0
    Yplot[:,-1]=0
    Yplot[0,:]=0
    Yplot[-1,:]=0
    # prikaži referenčno klasifikacijo
    ax[-2].imshow(Yplot)
    if Y[ix]==1:
        ax[-2].text(Yplot.shape[1]/2,Yplot.shape[0]/2,'MS aktivna',size=20,ha='center',va='center')
    else:
        ax[-2].text(Yplot.shape[1]/2,Yplot.shape[0]/2,'MS neaktivna',size=20,ha='center',va='center')
    ax[-2].set_title(titles[-2])
    ax[-2].axis('off')
    # prikaži klasifikacijo s CNN
    ax[-1].imshow(Yplot)
    if preds_t[ix]==1:
        ax[-1].text(Yplot.shape[1]/2,Yplot.shape[0]/2,'MS aktivna',size=20,ha='center',va='center')
    else:
        ax[-1].text(Yplot.shape[1]/2,Yplot.shape[0]/2,'MS neaktivna',size=20,ha='center',va='center')
    ax[-1].set_title(titles[-1])
    ax[-1].axis('off')
    if not(bool(preds_t[ix])^bool(Y[ix]))==1:
        print('Klasifikacija je pravilna.')
    else:
        print('Klasifikacija je nepravilna.')
    # OPOMBA: pretvorbo v format float32 pri prikazovanju opravimo, ker imshow ne podpira formata float16.

# %%
# Definicija funkcij za kvantitativno vrednotenje.

def dice(result, reference):
    result = np.atleast_1d(result.astype(np.bool))
    reference = np.atleast_1d(reference.astype(np.bool))
    intersection = np.count_nonzero(result & reference)
    size_i1 = np.count_nonzero(result)
    size_i2 = np.count_nonzero(reference)

    try:
        dc = 2. * intersection / float(size_i1 + size_i2)
    except ZeroDivisionError:
        dc = 0.0
    return dc

def analysisBoxplots(Title, iPos, iNeg, LABELS, DRAW=False):

    PVAL_THRESHOLD = 0.05
    # _, pval = ttest_ind(iPos, iNeg)    
    _, pval = mannwhitneyu(iPos, iNeg)
    sig = ('Not Significant','Significant')[int(pval < PVAL_THRESHOLD)]
    if DRAW==True:
        plt.figure(figsize=(5,5))
    plt.boxplot([iPos, iNeg],labels=LABELS)
    plt.title(
        '{bname}, pval={pval:.2f} ({sig})'.format(
            bname=Title,
            pval=pval,
            sig=sig
        )
    )

# Definicija funkcije za vrednotenje vpliva praga na Diceov koeficient.
def kThresholdDice(preds_train,Y_train,preds_test,Y_test):
    ktrain_dice=[]
    ktest_dice=[]
    kT=np.linspace(0,1,101)
    for k in range(kT.size):
        kpreds_train_t = (preds_train > kT[k]).astype(np.uint8)
        kpreds_test_t = (preds_test > kT[k]).astype(np.uint8)
        itrain_dice=[]
        itest_dice=[]
        for i in range(kpreds_train_t.shape[0]):
            itrain_dice.append(dice(kpreds_train_t[i].flatten(), Y_train[i].flatten()))
        for i in range(kpreds_test_t.shape[0]):
            itest_dice.append(dice(kpreds_test_t[i].flatten(), Y_test[i].flatten()))
        ktrain_dice.append(np.mean(itrain_dice))
        ktest_dice.append(np.mean(itest_dice))
    
    plt.figure(figsize=(5,5))
    plt.plot(kT,ktrain_dice,label='Train')
    plt.plot(kT,ktest_dice,label='Test')
    plt.legend()
    plt.title('Diceov koeficient v odvisnosti od vrednosti praga.')
    plt.xlabel('Threshold')
    plt.ylabel('Dice coefficient')
    plt.grid('on')
    
    return kT, ktrain_dice, ktest_dice

# Definicija funkcije za vrednotenje vpliva praga na Diceov koeficient.
def kThresholdDiceM2(preds_train,Y0_train,Y1_train,preds_test,Y0_test,Y1_test):
    ktrain_dice=[]
    ktest_dice=[]
    kT=np.linspace(0,1,101)
    for k in range(kT.size):
        kpreds_train_t01 = (preds_train > kT[k]).astype(np.uint8)
        kpreds_test_t01 = (preds_test > kT[k]).astype(np.uint8)
        kpreds_train_t=(kpreds_train_t01!=Y0_train).astype(np.uint8)
        kpreds_test_t=(kpreds_test_t01!=Y0_test).astype(np.uint8)
        itrain_dice=[]
        itest_dice=[]
        for i in range(kpreds_train_t.shape[0]):
            itrain_dice.append(dice(kpreds_train_t[i].flatten(), Y1_train[i].flatten()))
        for i in range(kpreds_test_t.shape[0]):
            itest_dice.append(dice(kpreds_test_t[i].flatten(), Y1_test[i].flatten()))
        ktrain_dice.append(np.mean(itrain_dice))
        ktest_dice.append(np.mean(itest_dice))
    
    plt.figure(figsize=(5,5))
    plt.plot(kT,ktrain_dice,label='Train')
    plt.plot(kT,ktest_dice,label='Test')
    plt.legend()
    plt.title('Diceov koeficient v odvisnosti od vrednosti praga.')
    plt.xlabel('Threshold')
    plt.ylabel('Dice coefficient')
    plt.grid('on')
    
    return kT, ktrain_dice, ktest_dice

# Definicija funkcije za vrednotenje vpliva praga na točnost.
def kThresholdACC(preds_train,Y0_train,Vs1_train,Y_train,preds_test,Y0_test,Vs1_test,Y_test,dv_threshold_2d):
    ktrain_ACC=[]
    ktest_ACC=[]
    kT=np.linspace(0,1,101)
    for k in range(kT.size):
        # Binarizacija maske M2p glede na trenutni prag.
        kpreds_train_t01 = (preds_train > kT[k]).astype(np.uint8)
        kpreds_test_t01 = (preds_test > kT[k]).astype(np.uint8)
        kpreds_train_t=(kpreds_train_t01!=Y0_train).astype(np.uint8)
        kpreds_test_t=(kpreds_test_t01!=Y0_test).astype(np.uint8)
        # Izračun volumna maske M2p.
        kVs2p_train=np.sum(np.sum((np.squeeze(kpreds_train_t)==1),axis=-1),axis=-1)/100 # Pretvorba iz mm**2 v cm**2.
        kVs2p_test=np.sum(np.sum((np.squeeze(kpreds_test_t)==1),axis=-1),axis=-1)/100 # Pretvorba iz mm**2 v cm**2.
        # Izračun razlike volumnov mask M2p-M1.
        kdVs2p1r_train=kVs2p_train-Vs1_train # Podano v cm**2.
        kdVs2p1r_test=kVs2p_test-Vs1_test # Podano v cm**2.
        # Izračun klasifikacije z binarizacijo spremembe volumna mask M2p-M1.
        kpredsdv_train = (kdVs2p1r_train > dv_threshold_2d).astype(np.uint8)
        kpredsdv_test = (kdVs2p1r_test > dv_threshold_2d).astype(np.uint8)
        # Izračun točnosti.
        kACC_train,_,_=Metrics(kpredsdv_train,Y_train)
        kACC_test,_,_=Metrics(kpredsdv_test,Y_test)
        ktrain_ACC.append(kACC_train)
        ktest_ACC.append(kACC_test)
    
    plt.figure(figsize=(5,5))
    plt.plot(kT,ktrain_ACC,label='Train')
    plt.plot(kT,ktest_ACC,label='Test')
    plt.legend()
    plt.title('Točnost v odvisnosti od vrednosti praga.')
    plt.xlabel('Threshold')
    plt.ylabel('ACC')
    plt.grid('on')
    
    return kT, ktrain_ACC, ktest_ACC
    
def Metrics(preds_t,Y):
    TN=np.count_nonzero((preds_t==0)&(Y==0))
    FN=np.count_nonzero((preds_t==0)&(Y==1))
    FP=np.count_nonzero((preds_t==1)&(Y==0))
    TP=np.count_nonzero((preds_t==1)&(Y==1))
    
    # Točnost.
    ACC=(TN+TP)/(TN+FN+FP+TP)
    # Občutljivost.
    TPR=TP/(FN+TP)
    # Specifičnost.
    TNR=TN/(TN+FP)
    
    return ACC, TPR, TNR
    
def analysisROC(Title, iPos, iNeg, DRAW=False):

    p = int((sum(iPos)/len(iPos)) > (sum(iNeg)/len(iNeg)))

    fpr, tpr, thrs = roc_curve([p] * len(iPos) + [1-p] * len(iNeg), iPos + iNeg)
    roc_auc = auc(fpr, tpr)

    if DRAW==True:
        plt.figure(figsize=(5,5))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('{bname}, ROC (AUC={auc:.2f})'.format(bname=Title.upper(),auc=roc_auc))
    plt.legend(loc="lower right")

# %%
# Nalaganje modela in izračun razgradnje na učni in testni zbirki.

# Nalaganje modela.
model = load_model(os.path.join(MODELS_PATH, MODEL_NAME), custom_objects={'dice_coef': dice_coef, 'dice_coef_loss': dice_coef_loss})

# OPOMBA: pri nalaganju modela, ki smo ga ustvarili v Google Colab, dobimo drugačne rezultate vrednotenje, kot če isti model testiramo v Google Colab. Pri obratni poti (testiranje modela,
# ustvarjenega v JupyterLab, v Google Colab) pa modela niti ne moremo naložiti. Razlog je v različnih nameščenih verzijah paketa Keras, ki pri istih klicanih parametrih uporablja v ozadju
# različne algoritme učenja in klicanja funkcij, kar povzroča nekompatibilnost pri uporabi istih modelov v različnih okoljih.

# OPOMBA: nalaganje modela v primeru uporabe lastne izgubne kriterijske funkcije.
# model = load_model(os.path.join(MODELS_PATH, MODEL_NAME), custom_objects={'dice_coef': dice_coef, 'dice_coef_loss': dice_coef_loss, 'weighted_cross_entropy': weighted_cross_entropy})

# Primerjava vrednosti kriterijskih funkcij med učno in testno zbirko.
print('Metrike modela:',model.metrics_names)
print('')
score = model.evaluate(X_train, Y01_train, verbose=0)
print('Učna zbirka')
print('\tloss:', score[0])
print('\tdice_coef:', score[1])
score = model.evaluate(X_test, Y01_test, verbose=0)
print('Testna zbirka')
print('\tloss:', score[0])
print('\tdice_coef:', score[1])
# Out:
# Metrike modela: ['loss', 'dice_coef']
#
# Učna zbirka
# 	loss: 0.0051543502038163425
# 	dice_coef: 0.5708460807800293
# Testna zbirka
# 	loss: 0.01715332828462124
# 	dice_coef: 0.228033185005188

# %%
# Razgradnja na učni in testni zbirki.
preds_train = model.predict(X_train, verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Binarizacija vrednosti.
preds_train_t01 = (preds_train > THRESHOLD).astype(np.uint8)
preds_test_t01 = (preds_test > THRESHOLD).astype(np.uint8)

# Rekonstrukcija maske M2.
preds_train_t=(preds_train_t01!=Y0_train)
preds_test_t=(preds_test_t01!=Y0_test)

# Preverba števila pikslov, pripadajočih lezijam.
np.sum(Y01_train.astype('uint8')), np.sum(preds_train_t.astype('uint8'))
# OPOMBA: preverba, ali dobimo pretirano število FP oz. FN pikslov.
# Out:
# 113/113 [==============================] - ETA:  - ETA:  - ETA:  - 4s 34ms/step
# 49/49 [==============================] - ETA:  - 2s 34ms/step
# (15814, 37017)

# %%
# VREDNOTENJE RAZGRADNJE

# %%
# Učna zbirka.

# %%
# Kvalitativno: kakovost razgradnje na učnih vzorcih (ali sploh deluje?)

# Preverjanje kakovosti razgradnje na učnih vzorcih (sanity check).
viewImagesOutput2d(X_train, Y01_train, preds_train_t01, Y0_train, Y1_train, preds_train_t, MODALITIES)

# %%
# Kvantitativno: izračun Diceovih koeficientov na učnih slikah.

train_dice_delta=[]
train_dice1r2r=[]
train_dice1r2p=[]
train_dice2p2r=[]
for i in range(preds_train_t.shape[0]):
    # Diceov kofiecient na izračunani razliki mask in referenčni razliki.
    train_dice_delta.append(dice(preds_train_t01[i].flatten(),Y01_train[i].flatten()))
    # Diceov koeficient na prvi maski in referenčni drugi maski.
    train_dice1r2r.append(dice(Y0_train[i].flatten(),Y1_train[i].flatten()))
    # Diceov koeficient na prvi maski in izračunani drugi maski.
    train_dice1r2p.append(dice(Y0_train[i].flatten(),preds_train_t[i].flatten()))
    # Diceov koeficient na izračunani drugi maski in referenčni drugi maski.
    train_dice2p2r.append(dice(preds_train_t[i].flatten(), Y1_train[i].flatten()))

# %%
# Statistična primerjava Diceovih koeficientov na učnih slikah.

print('Povprečna vrednost Diceovega koeficienta M1M2p-M1M2 na učni zbirki:', np.mean(train_dice_delta))
print('')
print('Povprečna vrednost Diceovega koeficienta M1-M2 na učni zbirki: ', np.mean(train_dice1r2r))
print('Povprečna vrednost Diceovega koeficienta M1-M2p na učni zbirki: ', np.mean(train_dice1r2p))
print('Povprečna vrednost Diceovega koeficienta M2p-M2 na učni zbirki: ', np.mean(train_dice2p2r))
print('')

plt.figure(figsize=(10,5))
plt.suptitle('Učna zbirka')
plt.subplot(1,2,1)
analysisBoxplots('Diceov koeficient', train_dice1r2r, train_dice2p2r, LABELS=['M1-M2','M2p-M2'])
# OPOMBA: vidimo, da se maska M1 enako dobro prekriva s ciljno masko M2 kot maska M2p. Z izračunano masko M2p torej statistično ne pridobimo nič v primerjavi z že dano masko M1 pri
# napovedi nove maske.
plt.subplot(1,2,2)
analysisBoxplots('Diceov koeficient', train_dice1r2p, train_dice2p2r, LABELS=['M1-M2p','M2p-M2'])
# OPOMBA: vidimo, da se je nevronska mreža naučila masko M2p bolj prilagoditi učnim maskam M1 kot ciljnim maskam M2.
# Out:
# Povprečna vrednost Diceovega koeficienta M1M2p-M1M2 na učni zbirki: 0.685024098766782
#
# Povprečna vrednost Diceovega koeficienta M1-M2 na učni zbirki:  0.7266561328316568
# Povprečna vrednost Diceovega koeficienta M1-M2p na učni zbirki:  0.7386402736002231
# Povprečna vrednost Diceovega koeficienta M2p-M2 na učni zbirki:  0.8379502416420946

# %%
# Volumen maske M2p.
Vs2p_train=np.sum(np.sum((np.squeeze(preds_train_t)==1),axis=-1),axis=-1)/100 # Pretvorba iz mm**2 v cm**2.

# Razlika M2-M1.
dVs2r1r_train=Vs2_train-Vs1_train # Podano v cm**2.
# Razlika M2p-M1
dVs2p1r_train=Vs2p_train-Vs1_train # Podano v cm**2.
# Razlika M2-M2p.
dVs2p2r_train=Vs2p_train-Vs2_train # Podano v cm**2.

# %%
# Statistični test (volumni).

print('Povprečna vrednost volumna M1 na učni zbirki: ', np.mean(Vs1_train))
print('Povprečna vrednost volumna M2 na učni zbirki: ', np.mean(Vs2_train))
print('Povprečna vrednost volumna M2p na učni zbirki: ', np.mean(Vs2p_train))
print('')

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
analysisBoxplots('V [cm**2]',Vs1_train,Vs2_train,['M1','M2'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.
plt.subplot(1,3,2)
analysisBoxplots('V [cm**2]',Vs1_train,Vs2p_train,['M1','M2p'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.
plt.subplot(1,3,3)
analysisBoxplots('V [cm**2]',Vs2p_train,Vs2_train,['M2p','M2'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.

# OPOMBA: vidimo, da se volumni presekov med seboj statistično ne razlikujejo.
# Out:
# Povprečna vrednost volumna M1 na učni zbirki:  3.0889380530973454
# Povprečna vrednost volumna M2 na učni zbirki:  3.1390265486725664
# Povprečna vrednost volumna M2p na učni zbirki:  3.2758407079646017

# %%
# Statistični test (spremembe volumnov).

print('Povprečna sprememba volumna M2-M1 na učni zbirki: ', np.mean(dVs2r1r_train))
print('Povprečna sprememba volumna M2p-M1 na učni zbirki: ', np.mean(dVs2p1r_train))
print('Povprečna sprememba volumna M2-M2p na učni zbirki: ', np.mean(dVs2p2r_train))
print('')

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
analysisBoxplots('dV [cm**2]',dVs2r1r_train,dVs2p1r_train,['M2-M1','M2p-M1'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.
plt.subplot(1,2,2)
analysisBoxplots('dV [cm**2]',dVs2p2r_train,dVs2p1r_train,['M2p-M2','M2p-M1'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.

# OPOMBA: iz 1. diagrama vidimo, da se spremembe volumnov M2-M1 in M2p-M1 statistično pomembno razlikujejo. Izračunana sprememba volumna rezine torej ni dober pokazatelj referenčne spremembe
# volumna rezine.
# OPOMBA: iz 2. diagrama vidimo, da se razliki volumnov M2-M2p in M2p-M1 ne razlikujeta statistično pomembno, kar kaže na enako oddaljenost maske M2p od maske M1 po razliki volumnov kot od maske
# M2.
# OPOMBA: iz obeh diagramov vidimo tudi, da je varianca razlik M2p-M1 zelo majhna, kar kaže na dobro sovpadanje volumnov mask M1 in M2p po posameznih pacientih in boljšo prilagoditev maske M2p
# med učenjem maski M1 kot maski M2.
# Out:
# Povprečna sprememba volumna M2-M1 na učni zbirki:  0.05008849557522122
# Povprečna sprememba volumna M2p-M1 na učni zbirki:  0.18690265486725666
# Povprečna sprememba volumna M2-M2p na učni zbirki:  0.13681415929203541

# %%
# Testna zbirka

# %%
# Kvalitativno: kakovost razgradnje na testnih vzorcih (zmožnost posploševanja).

# Preverjanje kakovosti razgradnje na naključno izbranih testnih vzorcih.
viewImagesOutput2d(X_test, Y01_test, preds_test_t01, Y0_test, Y1_test, preds_test_t, MODALITIES)

# %%
# Kvantitativno: vrednosti Diceovih koeficientov na testnih slikah.

test_dice_delta=[]
test_dice1r2r=[]
test_dice1r2p=[]
test_dice2p2r=[]
for i in range(preds_test_t.shape[0]):
    # Diceov kofiecient na izračunani razliki mask in referenčni razliki.
    test_dice_delta.append(dice(preds_test_t01[i].flatten(),Y01_test[i].flatten()))
    # Diceov koeficient na prvi maski in referenčni drugi maski.
    test_dice1r2r.append(dice(Y0_test[i].flatten(),Y1_test[i].flatten()))
    # Diceov koeficient na prvi maski in izračunani drugi maski.
    test_dice1r2p.append(dice(Y0_test[i].flatten(),preds_test_t[i].flatten()))
    # Diceov koeficient na izračunani drugi maski in referenčni drugi maski.
    test_dice2p2r.append(dice(preds_test_t[i].flatten(), Y1_test[i].flatten()))

# %%
# Statistična primerjava Diceovih koeficientov na testnih slikah.

print('Povprečna vrednost Diceovega koeficienta M1M2p-M1M2 na učni zbirki:', np.mean(test_dice_delta))
print('')
print('Povprečna vrednost Diceovega koeficienta M1-M2 na testni zbirki: ', np.mean(test_dice1r2r))
print('Povprečna vrednost Diceovega koeficienta M1-M2p na testni zbirki: ', np.mean(test_dice1r2p))
print('Povprečna vrednost Diceovega koeficienta M2p-M2 na testni zbirki: ', np.mean(test_dice2p2r))
print('')

plt.figure(figsize=(10,5))
plt.suptitle('Testna zbirka')
plt.subplot(1,2,1)
analysisBoxplots('Diceov koeficient', test_dice1r2r, test_dice2p2r, LABELS=['M1-M2','M2p-M2'])
# OPOMBA: vidimo, da dobimo na testnih podatkih podobne rezultate kot na učnih.
plt.subplot(1,2,2)
analysisBoxplots('Diceov koeficient', test_dice1r2p, test_dice2p2r, LABELS=['M1-M2p','M2p-M2'])
# OPOMBA: vidimo, da dobimo na testnih podatkih podobne rezultate kot na učnih.
# Out:
# Povprečna vrednost Diceovega koeficienta M1M2p-M1M2 na učni zbirki: 0.16769824631443642
#
# Povprečna vrednost Diceovega koeficienta M1-M2 na testni zbirki:  0.6830539827658659
# Povprečna vrednost Diceovega koeficienta M1-M2p na testni zbirki:  0.816472212739546
# Povprečna vrednost Diceovega koeficienta M2p-M2 na testni zbirki:  0.6251624261412139

# %%
# Volumen maske M2p.
Vs2p_test=np.sum(np.sum((np.squeeze(preds_test_t)==1),axis=-1),axis=-1)/100 # Pretvorba iz mm**2 v cm**2.

# Razlika M2-M1.
dVs2r1r_test=Vs2_test-Vs1_test # Podano v cm**2.
# Razlika M2p-M1
dVs2p1r_test=Vs2p_test-Vs1_test # Podano v cm**2.
# Razlika M2-M2p.
dVs2p2r_test=Vs2p_test-Vs2_test # Podano v cm**2.

# %%
# Statistični test (volumni).

print('Povprečna vrednost volumna M1 na testni zbirki: ', np.mean(Vs1_test))
print('Povprečna vrednost volumna M2 na testni zbirki: ', np.mean(Vs2_test))
print('Povprečna vrednost volumna M2p na testni zbirki: ', np.mean(Vs2p_test))
print('')

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
analysisBoxplots('V [cm**2]',Vs1_test,Vs2_test,['M1','M2'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.
plt.subplot(1,3,2)
analysisBoxplots('V [cm**2]',Vs1_test,Vs2p_test,['M1','M2p'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.
plt.subplot(1,3,3)
analysisBoxplots('V [cm**2]',Vs2p_test,Vs2_test,['M2p','M2'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.

# OPOMBA: vidimo, da dobimo podobne rezultate kot pri učni zbirki.
# Out:
# Povprečna vrednost volumna M1 na testni zbirki:  2.6255102040816327
# Povprečna vrednost volumna M2 na testni zbirki:  2.6273469387755104
# Povprečna vrednost volumna M2p na testni zbirki:  2.8687755102040815

# %%
# Statistični test (spremembe volumnov).

print('Povprečna sprememba volumna M2-M1 na testni zbirki: ', np.mean(dVs2r1r_test))
print('Povprečna sprememba volumna M2p-M1 na testni zbirki: ', np.mean(dVs2p1r_test))
print('Povprečna sprememba volumna M2p-M2 na testni zbirki: ', np.mean(dVs2p2r_test))
print('')

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
analysisBoxplots('dV [cm**2]',dVs2r1r_test,dVs2p1r_test,['M2-M1','M2p-M1'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.
plt.subplot(1,2,2)
analysisBoxplots('dV [cm**2]',dVs2p2r_test,dVs2p1r_test,['M2p-M2','M2p-M1'])
# OPOMBA: uporabljen Mann-Whitneyjev neparametrični statistični test.

# OPOMBA: vidimo, da dobimo podobne rezultate kot pri učni zbirki.
# Out:
# Povprečna sprememba volumna M2-M1 na testni zbirki:  0.001836734693877546
# Povprečna sprememba volumna M2p-M1 na testni zbirki:  0.24326530612244898
# Povprečna sprememba volumna M2p-M2 na testni zbirki:  0.24142857142857138

# %%
# Preverba vpliva praga THRESHOLD na Diceov koeficient med maskama M2p-M1 in maskama M2-M1.

kT_dice_delta, ktrain_dice_delta, ktest_dice_delta = kThresholdDice(preds_train,Y01_train,preds_test,Y01_test)
np.argmax(ktrain_dice_delta), kT_dice_delta[np.argmax(ktrain_dice_delta)], ktrain_dice_delta[np.argmax(ktrain_dice_delta)], ktest_dice_delta[np.argmax(ktrain_dice_delta)]
# Out:
# (46, 0.46, 0.6896338874826284, 0.18152539382820584)

# %%
# Preverba vpliva praga THRESHOLD na Diceov koeficient med maskama M2p in M2.

kT_dice, ktrain_dice, ktest_dice = kThresholdDiceM2(preds_train,Y0_train,Y1_train,preds_test,Y0_test,Y1_test)
np.argmax(ktrain_dice), kT_dice[np.argmax(ktrain_dice)], ktrain_dice[np.argmax(ktrain_dice)], ktest_dice[np.argmax(ktrain_dice)]
# Out:
# (54, 0.54, 0.8424685517210504, 0.6368978219703032)

# %%
# VREDNOTENJE RAZVRŠČANJA

# %%
# Preverba vpliva praga THRESHOLD na točnost.

kT_ACC, ktrain_ACC, ktest_ACC = kThresholdACC(preds_train,Y0_train,Vs1_train,Y_train[:,1],preds_test,Y0_test,Vs1_test,Y_test[:,1],DV_THRESHOLD_2D)
# OPOMBA: vidimo, da je glede na kriterij točnosti optimalni prag za testne podatke 0.5.
np.argmax(ktrain_ACC), kT_ACC[np.argmax(ktrain_ACC)], ktrain_ACC[np.argmax(ktrain_ACC)], ktest_ACC[np.argmax(ktrain_ACC)]
# Out:
# (50, 0.5, 0.8938053097345132, 0.5510204081632653)

# %%
# Učna zbirka

# %%
# Klasifikacija na podlagi maske M2p.
predsdv_train=np.zeros_like(dVs2p1r_train)
predsdv_train[dVs2p1r_train>DV_THRESHOLD_2D]=1

# %%
# Vrednotenje na posameznih slikah.

viewImagesOutputMS2d(X_train,Y_train[:,1],predsdv_train,MODALITIES)
# Out:
# Klasifikacija je pravilna.

# %%
# Razdelitev pacientov na tiste z aktivno MS in tiste z neaktivno MS.

Nr_train=np.count_nonzero(Y_train[:,0])
Ar_train=np.count_nonzero(Y_train[:,1])

Nr2d_train=np.count_nonzero(Y2D_train_t==0)
Ar2d_train=np.count_nonzero(Y2D_train_t==1)

Np_train=np.count_nonzero(predsdv_train==0)
Ap_train=np.count_nonzero(predsdv_train==1)

print('Referenčna klasifikacija:')
print('Število pacientov z neaktivno MS:',Nr_train)
print('Število pacientov z aktivno MS:',Ar_train)
print('')
print('Klasifikacija na podlagi sredinskih rezin referenčnih mask:')
print('Število pacientov z neaktivno MS:',Nr2d_train)
print('Število pacientov z aktivno MS:',Ar2d_train)
print('')
print('Izračunana klasifikacija:')
print('Število pacientov z neaktivno MS:',Np_train)
print('Število pacientov z aktivno MS:',Ap_train)
# Out:
# Referenčna klasifikacija:
# Število pacientov z neaktivno MS: 49
# Število pacientov z aktivno MS: 64
#
# Klasifikacija na podlagi sredinskih rezin referenčnih mask:
# Število pacientov z neaktivno MS: 51
# Število pacientov z aktivno MS: 62
#
# Izračunana klasifikacija:
# Število pacientov z neaktivno MS: 43
# Število pacientov z aktivno MS: 70

# %%
# Metrike kvalitete klasifikacije.

# Izračuni metrik.
ACCp_train,TPRp_train,TNRp_train=Metrics(predsdv_train,Y_train[:,1])

# Izpis rezultatov.
print('Rezultati razvrščanja na učnih podatkih (izračunana klasifikacija):')
print('Točnost:',ACCp_train)
print('Občutljivost:',TPRp_train)
print('Specifičnost:',TNRp_train)
print('')

# Izračuni metrik.
ACCr_train,TPRr_train,TNRr_train=Metrics(Y2D_train_t,Y_train[:,1])

print('Rezultati razvrščanja na učnih podatkih (referenčna klasifikacija):')
print('Točnost:',ACCr_train)
print('Občutljivost:',TPRr_train)
print('Specifičnost:',TNRr_train)
# Out:
# Rezultati razvrščanja na učnih podatkih (izračunana klasifikacija):
# Točnost: 0.8938053097345132
# Občutljivost: 0.953125
# Specifičnost: 0.8163265306122449
#
# Rezultati razvrščanja na učnih podatkih (referenčna klasifikacija):
# Točnost: 0.9646017699115044
# Občutljivost: 0.953125
# Specifičnost: 0.9795918367346939

# %%
# Izračun ROC krivulje

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
analysisROC('Aktivnost MS (predikcija)', dVs2p1r_train[Y_train[:,1]==0].tolist(), dVs2p1r_train[Y_train[:,1]==1].tolist())
plt.subplot(1,2,2)
analysisROC('Aktivnost MS (referenčna metoda)', Y2D_train[Y_train[:,1]==0].tolist(), Y2D_train[Y_train[:,1]==1].tolist())

# %%
# Testna zbirka

# %%
# Klasifikacija na podlagi maske M2p.
predsdv_test=np.zeros_like(dVs2p1r_test)
predsdv_test[dVs2p1r_test>DV_THRESHOLD_2D]=1

# %%
# Vrednotenje na posameznih slikah.

viewImagesOutputMS2d(X_test,Y_test[:,1],predsdv_test,MODALITIES)
# Out:
# Klasifikacija je pravilna.

# %%
# Razdelitev pacientov na tiste z aktivno MS in tiste z neaktivno MS.

Nr_test=np.count_nonzero(Y_test[:,0])
Ar_test=np.count_nonzero(Y_test[:,1])

Nr2d_test=np.count_nonzero(Y2D_test_t==0)
Ar2d_test=np.count_nonzero(Y2D_test_t==1)

Np_test=np.count_nonzero(predsdv_test==0)
Ap_test=np.count_nonzero(predsdv_test==1)

print('Referenčna klasifikacija:')
print('Število pacientov z neaktivno MS:',Nr_test)
print('Število pacientov z aktivno MS:',Ar_test)
print('')
print('Klasifikacija na podlagi sredinskih rezin referenčnih mask:')
print('Število pacientov z neaktivno MS:',Nr2d_test)
print('Število pacientov z aktivno MS:',Ar2d_test)
print('')
print('Izračunana klasifikacija:')
print('Število pacientov z neaktivno MS:',Np_test)
print('Število pacientov z aktivno MS:',Ap_test)
# Out:
# Referenčna klasifikacija:
# Število pacientov z neaktivno MS: 24
# Število pacientov z aktivno MS: 25
#
# Klasifikacija na podlagi sredinskih rezin referenčnih mask:
# Število pacientov z neaktivno MS: 25
# Število pacientov z aktivno MS: 24
#
# Izračunana klasifikacija:
# Število pacientov z neaktivno MS: 6
# Število pacientov z aktivno MS: 43

# %%
# Metrike kvalitete klasifikacije.

# Izračuni metrik.
ACCp_test,TPRp_test,TNRp_test=Metrics(predsdv_test,Y_test[:,1])

# Izpis rezultatov.
print('Rezultati razvrščanja na testnih podatkih (izračunana klasifikacija):')
print('Točnost:',ACCp_test)
print('Občutljivost:',TPRp_test)
print('Specifičnost:',TNRp_test)
print('')

# Izračuni metrik.
ACCr_test,TPRr_test,TNRr_test=Metrics(Y2D_test_t,Y_test[:,1])

print('Rezultati razvrščanja na testnih podatkih (referenčna klasifikacija):')
print('Točnost:',ACCr_test)
print('Občutljivost:',TPRr_test)
print('Specifičnost:',TNRr_test)
# Out:
# Rezultati razvrščanja na testnih podatkih (izračunana klasifikacija):
# Točnost: 0.5510204081632653
# Občutljivost: 0.92
# Specifičnost: 0.16666666666666666
#
# Rezultati razvrščanja na testnih podatkih (referenčna klasifikacija):
# Točnost: 0.9387755102040817
# Občutljivost: 0.92
# Specifičnost: 0.9583333333333334

# %%
# Izračun ROC krivulje

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
analysisROC('Aktivnost MS (predikcija)', dVs2p1r_test[Y_test[:,1]==0].tolist(), dVs2p1r_test[Y_test[:,1]==1].tolist())
plt.subplot(1,2,2)
analysisROC('Aktivnost MS (referenčna metoda)', Y2D_test[Y_test[:,1]==0].tolist(), Y2D_test[Y_test[:,1]==1].tolist())
